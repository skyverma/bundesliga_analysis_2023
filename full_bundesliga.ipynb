# %%
list_var = ['A,B,C','D,E,F','H,I,J']
print(list_var[1])

print(list_var[1].split(',')[1])

# %%
#QUESTION.1
str1 = 'A,B,C\nD,E,F\nH,I,J'

# %% [markdown]
# Use str1 and get a list of ['A,B,C','D,E,F','H,I,J']
#
# print the list
#
# Access elements C snd I and print them use .split method and indexing.

# %%
str1 = 'A,B,C\nD,E,F\nH,I,J'
a= str1.split('\n')
b= a[0].split(',')[2]
c= a[2].split(',')[1]
print(a)
print(b)
print(c)
# Out:
# ['A,B,C', 'D,E,F', 'H,I,J']
# C
# I

# %% [markdown]
# - Read a csv file and store the it a list.

# %%
csv = 'A, B, C \n D, E, F \n'
print(csv)
csv.split()
# Out:
# A, B, C
#  D, E, F
# ['A,', 'B,', 'C', 'D,', 'E,', 'F']

# %%
#csv file conating the budesliga legue data is to be read usig with open command and save as a list

# %%
#QUESTION-2
import numpy as np
import pandas as pd

bl_data = open('buds.csv')

a =bl_data.read()
print(a)
#Score for AUG-LEI
r2=a.split('\n')[2]

b=r2.split(",")[12]
#Score for BOC-FRE
r5=a.split('\n')[5]
c=r5.split(',')[17]
#Score for LEV-MAI
r13=a.split('\n')[13]
d=r13.split(',')[9]


print(b)
print(c)
print(d)
bl_data.close()
# Out:
# ,Home \ Away ,AUG ,BSC ,UNB ,BOC ,BRE ,DOR ,FRA ,FRE ,HOF ,KÖL ,LEI ,LEV ,MAI ,MÖN ,MUN ,SCH ,STU ,WOL
# ,FC Augsburg ,— ,0–2 ,1–0 ,0–1 ,2–1 ,0–3 ,1–2 ,0–4 ,1–0 ,1–3 ,3–3 ,1–0 ,1–2 ,1–0 ,1–0 ,1–1 ,1–1 ,1–1
# ,Hertha BSC ,2–0 ,— ,0–2 ,1–1 ,2–4 ,0–1 ,1–1 ,2–2 ,1–1 ,2–0 ,0–1 ,2–2 ,1–1 ,4–1 ,2–3 ,2–1 ,2–1 ,0–5
# ,Union Berlin ,2–2 ,3–1 ,— ,1–1 ,1–0 ,2–0 ,2–0 ,4–2 ,3–1 ,0–0 ,2–1 ,0–0 ,2–1 ,2–1 ,1–1 ,0–0 ,3–0 ,2–0
# ,VfL Bochum ,3–2 ,3–1 ,2–1 ,— ,0–2 ,1–1 ,3–0 ,0–2 ,5–2 ,1–1 ,1–0 ,3–0 ,1–2 ,2–1 ,0–7 ,0–2 ,2–3 ,1–5
# ,Werder Bremen ,0–1 ,1–0 ,1–2 ,3–0 ,— ,0–2 ,3–4 ,1–2 ,1–2 ,1–1 ,1–2 ,2–3 ,0–2 ,5–1 ,1–2 ,2–1 ,2–2 ,2–1
# ,Borussia Dortmund ,4–3 ,4–1 ,2–1 ,3–0 ,2–3 ,— ,4–0 ,5–1 ,1–0 ,6–1 ,2–1 ,1–0 ,2–2 ,5–2 ,2–2 ,1–0 ,5–0 ,6–0
# ,Eintracht Frankfurt ,1–1 ,3–0 ,2–0 ,1–1 ,2–0 ,1–2 ,— ,2–1 ,4–2 ,1–1 ,4–0 ,5–1 ,3–0 ,1–1 ,1–6 ,3–0 ,1–1 ,0–1
# ,SC Freiburg ,3–1 ,1–1 ,4–1 ,1–0 ,2–0 ,1–3 ,1–1 ,— ,2–1 ,2–0 ,0–1 ,1–1 ,2–1 ,0–0 ,0–1 ,4–0 ,2–1 ,2–0
# ,1899 Hoffenheim ,1–0 ,3–1 ,4–2 ,3–2 ,1–2 ,0–1 ,3–1 ,0–0 ,— ,1–3 ,1–3 ,1–3 ,4–1 ,1–4 ,0–2 ,2–0 ,2–2 ,1–2
# ,1. FC Köln ,3–2 ,5–2 ,0–1 ,0–2 ,7–1 ,3–2 ,3–0 ,0–1 ,1–1 ,— ,0–0 ,1–2 ,1–1 ,0–0 ,1–2 ,3–1 ,0–0 ,0–2
# ,RB Leipzig ,3–2 ,3–2 ,1–2 ,4–0 ,2–1 ,3–0 ,2–1 ,3–1 ,1–0 ,2–2 ,— ,2–0 ,0–3 ,3–0 ,1–1 ,4–2 ,2–1 ,2–0
# ,Bayer Leverkusen ,1–2 ,4–1 ,5–0 ,2–0 ,1–1 ,0–2 ,3–1 ,2–3 ,0–3 ,1–2 ,2–0 ,— ,2–3 ,2–2 ,2–1 ,4–0 ,2–0 ,2–2
# ,Mainz 05 ,3–1 ,1–1 ,0–0 ,5–2 ,2–2 ,1–2 ,1–1 ,1–1 ,1–0 ,5–0 ,1–1 ,0–3 ,— ,4–0 ,3–1 ,2–3 ,1–4 ,0–3
# ,Borussia Mönchengladbach ,2–0 ,1–0 ,0–1 ,2–0 ,2–2 ,4–2 ,1–3 ,0–0 ,3–1 ,5–2 ,3–0 ,2–3 ,0–1 ,— ,3–2 ,0–0 ,3–1 ,2–0
# ,Bayern Munich ,5–3 ,2–0 ,3–0 ,3–0 ,6–1 ,4–2 ,1–1 ,5–0 ,1–1 ,1–1 ,1–3 ,4–0 ,6–2 ,1–1 ,— ,6–0 ,2–2 ,2–0
# ,Schalke 04 ,2–3 ,5–2 ,1–6 ,3–1 ,2–1 ,2–2 ,2–2 ,0–2 ,0–3 ,0–0 ,1–6 ,0–3 ,1–0 ,2–2 ,0–2 ,— ,2–1 ,0–0
# ,VfB Stuttgart ,2–1 ,2–1 ,0–1 ,4–1 ,0–2 ,3–3 ,1–3 ,0–1 ,1–1 ,3–0 ,1–1 ,1–1 ,1–1 ,2–1 ,1–2 ,1–1 ,— ,0–1
# ,VfL Wolfsburg ,2–2 ,1–2 ,1–1 ,4–0 ,2–2 ,2–0,2–2 ,6–0,2–1,2–4,0–3,0–0,3–0,2–2 ,2–4,0–0,3–2,—
#
# 3–3
# 0–2
# 2–3

# %%
#QUESTION -3
p=b.split('–')
q=c.split('–')
r=d.split('–')
print(p)
if int(p[0])>int(p[1]):
  print("aug won")
elif int(p[0])<int(p[1]):
  print('lei won')
else:
  print("draw")

if int(q[0])>int(q[1]):
  print(' boc won')
elif int(q[0])<int(q[1]):
  print('fre won')
else:
  print("draw")
if int(r[0])>int(r[1]):
  print("lev won")
elif  int(r[0])<int(r[1]):
  print("mai won")
else:
  print("draw")
# Out:
# ['3', '3 ']
# draw
# fre won
# mai won

# %% [markdown]
# - Split the list (line wise)

# %%
#the list of data is splited to read entries line wise

# %%
bl_data = open('buds.csv')

a =bl_data.read()


a=a.split("\n")
print(a)
# Out:
# ['', ',Home \\ Away ,AUG ,BSC ,UNB ,BOC ,BRE ,DOR ,FRA ,FRE ,HOF ,KÖL ,LEI ,LEV ,MAI ,MÖN ,MUN ,SCH ,STU ,WOL ', ',FC Augsburg ,— ,0–2 ,1–0 ,0–1 ,2–1 ,0–3 ,1–2 ,0–4 ,1–0 ,1–3 ,3–3 ,1–0 ,1–2 ,1–0 ,1–0 ,1–1 ,1–1 ,1–1 ', ',Hertha BSC ,2–0 ,— ,0–2 ,1–1 ,2–4 ,0–1 ,1–1 ,2–2 ,1–1 ,2–0 ,0–1 ,2–2 ,1–1 ,4–1 ,2–3 ,2–1 ,2–1 ,0–5 ', ',Union Berlin ,2–2 ,3–1 ,— ,1–1 ,1–0 ,2–0 ,2–0 ,4–2 ,3–1 ,0–0 ,2–1 ,0–0 ,2–1 ,2–1 ,1–1 ,0–0 ,3–0 ,2–0 ', ',VfL Bochum ,3–2 ,3–1 ,2–1 ,— ,0–2 ,1–1 ,3–0 ,0–2 ,5–2 ,1–1 ,1–0 ,3–0 ,1–2 ,2–1 ,0–7 ,0–2 ,2–3 ,1–5 ', ',Werder Bremen ,0–1 ,1–0 ,1–2 ,3–0 ,— ,0–2 ,3–4 ,1–2 ,1–2 ,1–1 ,1–2 ,2–3 ,0–2 ,5–1 ,1–2 ,2–1 ,2–2 ,2–1 ', ',Borussia Dortmund ,4–3 ,4–1 ,2–1 ,3–0 ,2–3 ,— ,4–0 ,5–1 ,1–0 ,6–1 ,2–1 ,1–0 ,2–2 ,5–2 ,2–2 ,1–0 ,5–0 ,6–0 ', ',Eintracht Frankfurt ,1–1 ,3–0 ,2–0 ,1–1 ,2–0 ,1–2 ,— ,2–1 ,4–2 ,1–1 ,4–0 ,5–1 ,3–0 ,1–1 ,1–6 ,3–0 ,1–1 ,0–1 ', ',SC Freiburg ,3–1 ,1–1 ,4–1 ,1–0 ,2–0 ,1–3 ,1–1 ,— ,2–1 ,2–0 ,0–1 ,1–1 ,2–1 ,0–0 ,0–1 ,4–0 ,2–1 ,2–0 ', ',1899 Hoffenheim ,1–0 ,3–1 ,4–2 ,3–2 ,1–2 ,0–1 ,3–1 ,0–0 ,— ,1–3 ,1–3 ,1–3 ,4–1 ,1–4 ,0–2 ,2–0 ,2–2 ,1–2 ', ',1. FC Köln ,3–2 ,5–2 ,0–1 ,0–2 ,7–1 ,3–2 ,3–0 ,0–1 ,1–1 ,— ,0–0 ,1–2 ,1–1 ,0–0 ,1–2 ,3–1 ,0–0 ,0–2 ', ',RB Leipzig ,3–2 ,3–2 ,1–2 ,4–0 ,2–1 ,3–0 ,2–1 ,3–1 ,1–0 ,2–2 ,— ,2–0 ,0–3 ,3–0 ,1–1 ,4–2 ,2–1 ,2–0 ', ',Bayer Leverkusen ,1–2 ,4–1 ,5–0 ,2–0 ,1–1 ,0–2 ,3–1 ,2–3 ,0–3 ,1–2 ,2–0 ,— ,2–3 ,2–2 ,2–1 ,4–0 ,2–0 ,2–2 ', ',Mainz 05 ,3–1 ,1–1 ,0–0 ,5–2 ,2–2 ,1–2 ,1–1 ,1–1 ,1–0 ,5–0 ,1–1 ,0–3 ,— ,4–0 ,3–1 ,2–3 ,1–4 ,0–3 ', ',Borussia Mönchengladbach ,2–0 ,1–0 ,0–1 ,2–0 ,2–2 ,4–2 ,1–3 ,0–0 ,3–1 ,5–2 ,3–0 ,2–3 ,0–1 ,— ,3–2 ,0–0 ,3–1 ,2–0 ', ',Bayern Munich ,5–3 ,2–0 ,3–0 ,3–0 ,6–1 ,4–2 ,1–1 ,5–0 ,1–1 ,1–1 ,1–3 ,4–0 ,6–2 ,1–1 ,— ,6–0 ,2–2 ,2–0 ', ',Schalke 04 ,2–3 ,5–2 ,1–6 ,3–1 ,2–1 ,2–2 ,2–2 ,0–2 ,0–3 ,0–0 ,1–6 ,0–3 ,1–0 ,2–2 ,0–2 ,— ,2–1 ,0–0 ', ',VfB Stuttgart ,2–1 ,2–1 ,0–1 ,4–1 ,0–2 ,3–3 ,1–3 ,0–1 ,1–1 ,3–0 ,1–1 ,1–1 ,1–1 ,2–1 ,1–2 ,1–1 ,— ,0–1 ', ',VfL Wolfsburg ,2–2 ,1–2 ,1–1 ,4–0 ,2–2 ,2–0,2–2 ,6–0,2–1,2–4,0–3,0–0,3–0,2–2 ,2–4,0–0,3–2,— ', '']

# %% [markdown]
# - Match Team short names to their expanded team names

# %%
r0=a[0].split('\n')
r1=a[1].split("\n")
r2=a[1].split("\n")
r3=a[2].split("\n")
r4=a.split("\n")[4]
r5=a.split("\n")[5]
r6=a.split("\n")[6]
r7=a.split('\n')[7]
r8=a.split("\n")[8]
r9=a.split("\n")[9]
r10=a.split("\n")[10]
r11=a.split("\n")[11]
r12=a.split("\n")[12]
r13=a.split("\n")[13]
r14=a.split('\n')[14]
r15=a.split("\n")[15]
r16=a.split("\n")[16]
r17=a.split("\n")[17]
r18=a.split("\n")[18]
r19=a.split("\n")[19]

print(r19)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-d6bd9ac6730f> in <cell line: 5>()
#       3 r2=a[1].split("\n")
#       4 r3=a[2].split("\n")
# ----> 5 r4=a.split("\n")[4]
#       6 r5=a.split("\n")[5]
#       7 r6=a.split("\n")[6]
#
# AttributeError: 'list' object has no attribute 'split'

# %%
# team names have to matched like "SC Freiburg ---> FRE"

# %%
row2=r2.split(",")
print(row2)
row2_0=row2[0]
row2_1=row2[1]
row2_2=row2[2]
row2_3=row2[3]
row2_4=row2[4]
row2_5=row2[5]
row2_6=row2[6]
row2_7=row2[7]
row2_8=row2[8]
row2_9=row2[9]
row2_10=row2[10]
row2_11=row2[11]
row2_12=row2[12]
row2_13=row2[13]
row2_14=row2[14]
row2_15=row2[15]
row2_16=row2[16]
row2_17=row2[17]
row2_18=row2[18]
row2_19=row2[19]

print(row2_19)

score_aug_aug=row2_2.split('–')
score_aug_bsc=row2_3.split('–')
score_aug_unb=row2_4.split('–')
score_aug_boc=row2_5split('–')
score_aug_bre=row2_6.split('–')
score_aug_dor=row2_7.split('–')
score_aug_fra=row2_8.split('–')
score_aug_fre=row2_9.split('–')
score_aug_hof=row2_10.split('–')
score_aug_kol=row2_11.split('–')
score_aug_lei=row2_12.split('–')
score_aug_lev=row2_13.split('–')
score_aug_mai=row2_14.split('–')
score_aug_mon=row2_15.split('–')
score_aug_mun=row2_16.split('–')
score_aug_seh=row2_17.split('–')
score_aug_stu=row2_18.split('–')
score_aug_wol=row2_19.split('–')
print(score_aug_wol)

# %%
print(r2)

# %% [markdown]
# - Print the win/loss for all games played by a single team

# %%
#print win/loss by first team for all matches by it

# %% [markdown]
# - Use a for loop to iterate over all entries of all team and decide win/loss/draw.

# %%
#using for loop do it for all the the teams

# %%
team=list(range(18))

# %% [markdown]
# - Use a different list for each team a store their number of wins/loss/draw separately

# %%
#make list for each team to store their total number of wins/loss/draw in order

# %% [markdown]
# - Use the above created list to calculate the points scored by each team and store the scores in a new list

# %%
#calculate the points scored

# %% [markdown]
# - Read the entries in the table to calculate goals_taken,goals_Scored and store it 3 different lists.

# %%
#read the table to calculate the goals taken etc. for each team adn store it a list

# %% [markdown]
# - Find the team with highest points, highest goal scored, highest wins.

# %%
# find the team with highest points, highest goal scored and highest wins

# %% [markdown]
# - Write team matching exercise to a file and save it.

# %%
#write back the team short and full matching exercise with their total scored to file named short-full.txt    eg. SC Freiburg-FEC-59
